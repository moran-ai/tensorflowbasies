# %%
import tensorflow as tf
# Out:
# F:\Anaconda\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
hello = tf.constant('Hello,Tensorflow')
sess = tf.Session()
print(sess.run(hello))
# Out:
# b'Hello,Tensorflow'

# %%
# 定义计算(在计算图中)
# 声明常量
a = tf.constant([1,2],name='a')
b = tf.constant([2,3],name='b')
result = a+ b
print(result)
# Out:
# Tensor("add:0", shape=(2,), dtype=int32)

# %%
# 执行计算(在会话中)
sess = tf.Session()
print(sess.run(result))
# Out:
# [3 5]

# %%
import numpy as np

# %%
x_data = np.float32(np.random.rand(2,100))
y_data = np.float32(np.dot([0.1,0.2],x_data)+0.3)

# %%
w = tf.Variable(tf.zeros([1,2]))
bias = tf.Variable(tf.zeros([1]))

# 构建线性方程
y = tf.matmul(w,x_data)+bias
# print(y_data)
print(y)
# Out:
# Tensor("add_1:0", shape=(1, 100), dtype=float32)

# %%
# sess = tf.Session()
# print(sess.run(y))
loss = tf.reduce_mean(tf.square(y - y_data))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

init = tf.global_variables_initializer()

# %%
sess = tf.Session()
sess.run(init)  # 初始化
sess.run(train)

# %%
for i in range(100):
    w1,b1 = sess.run([w,bias])
    print(w1,b1)
    sess.run(train)     # 模型训练
sess.close()
# pre_y = sess.run(y)
# sess.close()
# print(pre_y)
# Out:
# [[0.2154127  0.22072248]] [0.43894508]
# [[0.11030085 0.12430111]] [0.23684813]
# [[0.15344074 0.17368758]] [0.33024293]
# [[0.12867618 0.15548158]] [0.2873716]
# [[0.13562323 0.16809365]] [0.30728847]
# [[0.12832302 0.16618049]] [0.29822904]
# [[0.1279327  0.17067048]] [0.3025023]
# [[0.12467001 0.17193745]] [0.30060607]
# [[0.12301881 0.17443983]] [0.30153412]
# [[0.12088809 0.17614119]] [0.30114266]
# [[0.11921998 0.17799789]] [0.3013444]
# [[0.11756006 0.17958522]] [0.30125955]
# [[0.11609941 0.18111393]] [0.30129552]
# [[0.11473307 0.18250069]] [0.30126613]
# [[0.11349394 0.18379666]] [0.30125865]
# [[0.11235265 0.18499006]] [0.30123413]
# [[0.11130972 0.1860972 ]] [0.30121166]
# [[0.11035297 0.18712063]] [0.30118346]
# [[0.10947704 0.18806846]] [0.301154]
# [[0.10867435 0.18894555]] [0.30112198]
# [[0.10793919 0.18975759]] [0.30108872]
# [[0.10726575 0.19050927]] [0.3010542]
# [[0.10664895 0.19120523]] [0.30101898]
# [[0.10608403 0.1918496 ]] [0.30098322]
# [[0.10556667 0.19244628]] [0.30094728]
# [[0.10509289 0.19299878]] [0.30091134]
# [[0.10465904 0.19351044]] [0.3008756]
# [[0.10426179 0.19398431]] [0.30084023]
# [[0.10389806 0.19442321]] [0.30080533]
# [[0.10356506 0.19482975]] [0.3007711]
# [[0.1032602  0.19520633]] [0.30073753]
# [[0.10298114 0.1955552 ]] [0.3007048]
# [[0.10272568 0.19587839]] [0.30067292]
# [[0.10249187 0.19617783]] [0.30064192]
# [[0.10227789 0.19645528]] [0.3006119]
# [[0.10208206 0.19671237]] [0.30058283]
# [[0.10190287 0.19695064]] [0.30055478]
# [[0.1017389  0.19717145]] [0.3005277]
# [[0.10158889 0.1973761 ]] [0.30050164]
# [[0.10145164 0.19756578]] [0.30047658]
# [[0.10132609 0.1977416 ]] [0.30045253]
# [[0.10121125 0.19790459]] [0.30042943]
# [[0.10110622 0.1980557 ]] [0.30040732]
# [[0.10101016 0.19819579]] [0.30038616]
# [[0.10092232 0.19832568]] [0.30036592]
# [[0.100842   0.19844612]] [0.3003466]
# [[0.10076856 0.19855781]] [0.30032817]
# [[0.10070142 0.19866137]] [0.30031055]
# [[0.10064007 0.19875744]] [0.3002938]
# [[0.10058397 0.19884653]] [0.30027783]
# [[0.10053272 0.19892918]] [0.30026266]
# [[0.10048587 0.19900583]] [0.3002482]
# [[0.10044308 0.19907695]] [0.30023447]
# [[0.10040399 0.19914293]] [0.30022144]
# [[0.10036826 0.19920413]] [0.30020905]
# [[0.10033565 0.19926094]] [0.3001973]
# [[0.10030586 0.19931364]] [0.30018616]
# [[0.10027866 0.19936255]] [0.3001756]
# [[0.10025382 0.19940792]] [0.3001656]
# [[0.10023116 0.19945005]] [0.30015615]
# [[0.10021046 0.19948913]] [0.30014718]
# [[0.10019157 0.19952542]] [0.30013868]
# [[0.10017435 0.1995591 ]] [0.30013067]
# [[0.10015862 0.19959037]] [0.30012307]
# [[0.10014429 0.19961941]] [0.3001159]
# [[0.10013121 0.19964635]] [0.30010912]
# [[0.10011929 0.19967139]] [0.30010274]
# [[0.10010841 0.19969462]] [0.3000967]
# [[0.1000985 0.1997162]] [0.30009097]
# [[0.10008947 0.19973624]] [0.3000856]
# [[0.10008124 0.19975485]] [0.3000805]
# [[0.10007374 0.19977213]] [0.3000757]
# [[0.10006692 0.1997882 ]] [0.3000712]
# [[0.10006069 0.1998031 ]] [0.30006695]
# [[0.10005503 0.19981696]] [0.30006292]
# [[0.10004988 0.19982983]] [0.30005914]
# [[0.1000452  0.19984178]] [0.3000556]
# [[0.10004093 0.19985288]] [0.30005223]
# [[0.10003705 0.19986321]] [0.30004907]
# [[0.10003353 0.1998728 ]] [0.3000461]
# [[0.10003033 0.19988172]] [0.30004328]
# [[0.10002741 0.19989   ]] [0.30004066]
# [[0.10002476 0.19989769]] [0.30003816]
# [[0.10002236 0.19990486]] [0.30003583]
# [[0.10002018 0.1999115 ]] [0.30003363]
# [[0.1000182  0.19991769]] [0.30003157]
# [[0.10001641 0.19992343]] [0.30002964]
# [[0.10001478 0.19992876]] [0.30002782]
# [[0.1000133  0.19993372]] [0.3000261]
# [[0.10001197 0.19993834]] [0.30002448]
# [[0.10001075 0.19994263]] [0.30002296]
# [[0.10000966 0.19994663]] [0.30002156]
# [[0.10000866 0.19995034]] [0.30002022]
# [[0.10000776 0.19995378]] [0.30001897]
# [[0.10000694 0.19995698]] [0.30001777]
# [[0.10000621 0.19995998]] [0.30001667]
# [[0.10000554 0.19996275]] [0.30001563]
# [[0.10000495 0.19996534]] [0.30001467]
# [[0.1000044  0.19996773]] [0.30001375]
# [[0.10000391 0.19996996]] [0.3000129]
